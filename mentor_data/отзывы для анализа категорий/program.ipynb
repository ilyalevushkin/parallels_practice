# %% [markdown]
# # Слияние двух датасетов

# %%
import pandas as pd

# %%
frame = pd.read_csv('appstore_parallels_categories.csv', header=0, sep=',')

# %%
frame
# Out:
#                                                 review  categories
# 0    Paid for 1 year for 3990 rubles, but the licen...           1
# 1                                   beyond expectation           0
# 2                                            very good           0
# 3    There was a two-week trial version\nI made a p...           1
# 4    The charges are too expensive, and they are ch...           1
# 5    downloaded, immediately after registration a m...           1
# 6    I entered the card data for the subscription, ...           1
# 7    The best you can think of. Windows is just in ...           6
# 8             can get this dumb app to connect to wifi           4
# 9     Don't recommend for games. Won't be subscribing.           4
# 10   You can't enter without a subscription, you ha...           1
# 11   THEY FIRST REGISTER YOU WITH ALL YOUR DATA, TH...           1
# 12   Parallel performance is very satisfactory, but...           1
# 13   Does not have OpenGL support in the NVIDIA Gef...           4
# 14                                 only litel bit lagy           5
# 15   Downloading win system is too slow, 500m broad...           5
# 16   I didn't think it was so powerful ... really n...           0
# 17   I didn't test the app, I was just VERY dissati...           1
# 18   I am giving it 3 stars only because it has all...           6
# 19   Have been using VMware Fusion for over 15 year...           5
# 20                     This application does not work.           6
# 21                     This application does not work.           6
# 22   I love an app that just does what promisses to...           0
# 23   Tried in vain to connect multiple times .I hav...           4
# 24                                     Great APP!!!!!!           0
# 25   My frustration that PowerBI didnt work well on...           4
# 26                                                   1           0
# 27                  What the title says. It won't open           6
# 28   Well, the lite version was great. I used it fo...           1
# 29   There is no option to use a free version of th...           1
# 30      parallels desktop is the best virtual machince           0
# 31   I bought a Macbook pro 2020 because the Macboo...           6
# 32   I understand that companies would rather get p...           1
# 33   I understand that companies would rather get p...           1
# 34   There is no 14-day trial at all, no 14-day tri...           1
# 35   The software is good, just to pay. The reason ...           4
# 36             Best virtualization experience in MACOS           0
# 37       Subscribe to activate, how to use without key           1
# 38   the application when opening it charges you mo...           1
# 39   Uraaa finally there is a program that download...           4
# 40                                 works really well .           0
# 41                            cant connect my platform           4
# 42                               SO GLAD IT WORKS!!!!!           0
# 43                        please dont say that is free           1
# 44   They just billed and debited the trial version...           1
# 45                    app really good, nothing to say.           0
# 46   constantly tells me that I have no space for t...           4
# 47   It was clearly written on the page. Trial for ...           1
# 48   The app store version of Parallels suffers fro...           4
# 49   hi I upgrade my ios and windows stop working, ...           6
# 50   Download the app, and I could never see the sh...           6
# 51   You can't try it without a subscription, super...           1
# 52   After paying € 80 he constantly hangs on me an...           1
# 53   To work from home, I needed an environment exa...           1
# 54   Install the program and then the birds want 80...           1
# 55   Trial expired in the App Store and paid 96,000...           1
# 56   Parallels has chosen to handicap this product,...           6
# 57   tried both VMWare and Oracle - one problem. An...           5
# 58   I forgot the trial period when I used it more,...           1
# 59   This is VERY mislealeading and I cannot see ho...           1
# 60   Expensive, subscription formula ... long gone ...           1
# 61                                                well           0
# 62   Worked with all virtual machines. At the same ...           4
# 63          good but expensive, please make it cheaper           1
# 64    easy to install and so practical to use your mac           6
# 65   parallels is crap. vm isn't started sporadical...           4
# 66   Amazing program, no complications, everything ...           6
# 67   After opening it, I reminded me to activate my...           6
# 68   It works well however it makes the computer so...           6
# 69                                               so so           0
# 70   Running OSX Catalina 10.50.4 but, wanted to co...           4
# 71   I first downloaded parallels because i needed ...           6
# 72   I want to see the speed of this version first,...           1
# 73   Hello\nIt's nothing but Windows-related work, ...           1
# 74   The description doesn't mention any subscripti...           1
# 75   I downloaded the program in the app store, aft...           1
# 76   Requesting money directly ... kotz!\nThank God...           1
# 77         Does not work oar, this lance then this fig           0
# 78   The application promises a trial period, but t...           1
# 79   You pay 80 euros and it only lets you install ...           1
# 80   We don't have to look for a few days to solve ...           6
# 81                                                good           0
# 82   I’ve reviewed everything, I can’t find anywher...           4
# 83    Can't enter Win's interface without subscribing?           1
# 84   The WiFi does not work and the wired network d...           4
# 85   it did not let me link the operating system wi...           6
# 86   Great program, of course not free, but support...           6
# 87   I am confident that I have a lonely problem th...           5
# 88   Great software, absolutely amazed on how well ...           0
# 89   Great application, but it would be nice if you...           1
# 90   Works fine in general and I prefer it to the o...           6
# 91   Works fine in general and I prefer it to the o...           6
# 92   If you get like this you end up making yoursel...           1
# 93   It's great. I bought a Mac because I was fed u...           6
# 94   Kind of slow. It crashes or there is a delay, ...           5
# 95   It turned out to be a very unreliable program ...           6
# 96           do all you need to do in one installation           6
# 97   Love the experience I hope that you continue t...           4
# 98   On iMac, you can use only 4 processor cores, 8...           4
# 99   I've subscribed for the trial, but the softwar...           1
# 100  Long time user of previous versions. This app ...           6
# 101  Win10 cannot be activated, there is no help or...           6
# 102  Great application! Makes all the difference in...           0
# 103                                 It's not free app.           1
# 104  It automatically payed for the plan so i am re...           1
# 105  You have to pay or agree to a subscription rig...           1
# 106  costs 80 EUR / year as a subscription. Even if...           1
# 107  Program does exactly what it promises, runs op...           0
# 108  I was using a different virtual drive, but I t...           1
# 109  I was used to Parallels 15\ndownloaded from th...           4
# 110            Simple and everything works! Excellent!           0
# 111  I laready purchased one yaer subscription. but...           1
# 112  I didn't even use the app. I deleted a review ...           1
# 113  The previous version told me to buy a new one ...           6
# 114  Parallels focrces you into the subscription li...           1
# 115  Excellent experience & move around on windows ...           0
# 116           the PC on my Mac Mini at home is better.           0
# 117  I can just download a window iso on an externa...           1
# 118  How do I cancel my subscription? I am looking ...           1
# 119  I just need to run a couple software programs ...           4
# 120  So, I upgraded. But where's the 1 year free li...           1
# 121  worked right away and without studying the ins...           6
# 122  The app itself works perfectly, but unfortunat...           1
# 123  Virtual Machine with excellent software suppor...           6
# 124  No flaws and straight forward app. I needed to...           4
# 125  After the info came I should register it was d...           0
# 126                         Nice fake free application           1
# 127  Family sharing is not easy. This requires a su...           1
# 128                 Hello. Windows 7 can be installed?           4
# 129  The speed is amazing, I highly recommend it. I...           5
# 130  I used to love this product, and over the year...           4
# 131  It is useless to download it if you do not wan...           1
# 132  This is one of the best things happened to Apple!           0
# 133                                                  .           0
# 134  I eventually figured out how to install an old...           6
# 135                                             top sw           0
# 136  Since it seems to be not paid, it seems to be ...           1
# 137  So many apps are not so compatible. like SAP 2...           4
# 138  This new version is a lot slower than what I a...           5
# 139                      JUST WANT TO BUY NO SUBSCRIBE           1
# 140  Excellent app, but VERY EXPENSIVE if you think...           1
# 141  i have almost two weeks tryng to work it and i...           6
# 142  it won't let me activate it, it tells me that ...           1
# 143  Please contact us for automatic payment. Pleas...           1
# 144                                 it's too expensive           1
# 145  Beaucouop faster than the last version of Virt...           5
# 146  When you run programs that demand a lot of ram...           4
# 147  It would be good to know that this is not free...           1
# 148  I'm sorry, but how is this worth $80 dollars a...           1
# 149  I am a new network  student, this is my first ...           6
# 150  Most of the negative reviews were due to low m...           6
# 151  In principle, it works pretty well, but the fa...           1
# 152  Great app! I use the desktop version. I also t...           1
# 153                                             thanks           0
# 154                       Perfect on my macbook pro 16           0
# 155  It's been settled automatically, but, please a...           1
# 156  another product thats want to charge you for t...           1
# 157  🖕🏼FUK THEM !!!!!!!THIS APP DOES NOT UNINSTALL ...           0
# 158                                        really good           0
# 159                              I can't tie it up. :)           0
# 160  After the trial version, I paid for it officia...           1
# 161  At least also set up a notice of inquiry for t...           1
# 162                           The program ... fly away           0
# 163  I would like to get a refund . It's a great ap...           1
# 164  Paid for a subscription, only to find out one ...           1
# 165  1. Why are there no terms of use in Russian on...           1
# 166  Been paying these people for 3 years and final...           6
# 167  I just downloaded the application from the app...           6
# 168  Version 1.4 no longer allows you to use "free"...           1
# 169                                          Brilliant           0
# 170  According to their website they collect more t...           6
# 171  I bought the program 2 years ago, started to f...           1
# 172  Price far too high, despite the excellent serv...           1
# 173  No Issues to date. Works like a charm. Thanks ...           0
# 174  Everything is very bad. Even the free VirtualB...           4
# 175    It is really perfect i used. Bootcam really sck           0
# 176  This is a significant downgrade from previous ...           6
# 177  When I received it because it was a trial vers...           1
# 178  Don't bother with using Parallels. It have bec...           5
# 179                                          Excellent           0
# 180  The product that deserves its money, which I h...           1
# 181  Essential application for those of us who work...           0
# 182         I made a desktop remote connection, super.           4
# 183  This is not a cheap piece of software. I would...           1
# 184                 good use for mac and windows users           0
# 185  why would you pay a subscription for this garb...           1
# 186  Very expensive for those who just want to run ...           1
# 187  Was working fine yesterday. Start today and ca...           6
# 188                               I waited and waited!           0
# 189  During the free trial, I sent an email to stop...           1
# 190  After I bought it it worked for a short period...           6
# 191                      excelent very nice aplication           0
# 192  This application is not free. When you lanched...           1
# 193  It is explained that you can use Windows, so I...           4
# 194  This used to be good. But now they're charging...           1
# 195  I wish I had known about Parallels Desktop Lit...           6
# 196    INCORRECT COMPANY .... SEND THEM TO STRAFOTTERE           0
# 197  It was said "15 days trial period" but after c...           1
# 198  I already have Parallels Desktop for Mac runni...           1
# 199  Before the end of the two weeks of free trial,...           1
# 200  Even after a lot of googling, no network funct...           4
# 201  Everything  I wanted to use windows for was to...           6
# 202                                        IT PAYS END           1
# 203  Assuming that I will receive a full version af...           1
# 204  The app hasn't been updated in a while and I'm...           6
# 205  Everything works, I come from the full version...           6
# 206  It was supposed to be paid after a free trial,...           1
# 207  No mention of the compulsory subscription unti...           1
# 208  Completely unsatisfied. \nBought the product w...           6
# 209  I'm thankful to God for parallels. I upgraded ...           4
# 210  For when update optimized for catalina. When u...           4
# 211  It is amazing because you can do different thi...           0
# 212                   Excellent app, it costs too much           0
# 213  I wrote an old version and upgraded it to this...           5
# 214                        Worked great no complaints.           0
# 215  put the software in free access and display th...           1
# 216      Did not happen. Crouched a second time to buy           1
# 217  Please note that this is not free software. Wh...           1
# 218  I have windows installed on the partition. Whe...           6
# 219  This app works great with my mac! Easy to swit...           6
# 220  This is really great! I could switch anything ...           6
# 221  Parallels Desktop Lite is very intuitive to us...           0
# 222  The Parallels website description says that Li...           1
# 223  After installation, it is the subscription scr...           1
# 224  Works seamlessly. But if all you need to do is...           1
# 225  I hate when apps do this. Free to install but ...           1
# 226  I cannot get this mac to put my documents on i...           0
# 227  I purchased Paral 15 and canceled and deleted ...           1
# 228  I used to be a Parallels user in the past, bef...           1
# 229  The intro of this listing is very misleading. ...           1
# 230  simple to use even by less experienced people,...           6
# 231  the cost is high and windows 10\n need to acti...           1
# 232  I'm only interested in running Linux occasiona...           1
# 233  On the official site, it seems that the versio...           1
# 234  I could not get the internet to work, tried ev...           4
# 235  The good thing about Parallels Lite was that i...           1
# 236  This app should not be on App Store in my hone...           1
# 237  I have used Parallels in the past, and have be...           1
# 238                For the purpose I needed is solving           0
# 239  Apparently everything on the web talking about...           1
# 240  I have to admit, I bought my mbp before I got ...           6
# 241    The best virtual machine I know! Recommendable!           0
# 242  A very good program, especially the integratio...           4
# 243  What is the use of free, if you can’t use any ...           1
# 244  It used to be free and is still listed as free...           1
# 245  If you want to install Linux for free, you don...           1
# 246  Not 100% compatible with macOS Catalina and th...           4
# 247  it is disappointing i can not get the windows ...           4
# 248  Even as a beginner, installing an OS and getti...           6
# 249  This program is free to download and for 14 da...           1
# 250  Now requires an active paid subscription to in...           1
# 251  I can't use it because the mouse clicks or the...           4
# 252  Good but too expensive with over 70 euros a ye...           1
# 253  Stupid support. Trying to write a request for ...           0
# 254  In the name of the App there is written Lite w...           1
# 255  I would recommend to everyone. I needed a solu...           0
# 256  I did not use it after installing the test car...           1
# 257  Also, after the free trial, the automatic paym...           1
# 258  This app is NOT free, and should not be advert...           1
# 259  It turns out that after the test they charged ...           1
# 260  Lite version, just to try it for 14 days ... t...           1
# 261    Add coherence mode and you'd have a winner here           4
# 262  You can't use Parallels Desctop Lite without s...           1
# 263  Using on macbook pro i7 16gb. VM resource 8GB ...           4
# 264  it is checked very often and many times it is ...           5
# 265  PARALLELS doesn't mention the update to versio...           1
# 266  A touch expensive, but runs very well. Much sm...           4
# 267  What can I do to prevent payment after the fre...           1
# 268  its a really raw version of 10. Not only do th...           1
# 269  I remember when this was £45 with no renewing ...           1
# 270  I'm using it after subscribing in Mojave. Exte...           6
# 271  The application is not free, immediately upon ...           1
# 272  Works fine in general and I prefer it to the o...           6
# 273  I defenitely do not recall making any agreemen...           1
# 274  Only tells you about the 14 day trial once you...           1
# 275  Excellent solution, a little complicated to ac...           5
# 276  pity it costs so much annual subscription to h...           1
# 277  This should be a cheaper product, or supplied ...           1
# 278  stable work; not so demanding on apartanny res...           6
# 279  It is ridiculous that it cannot connect to the...           4
# 280  Neither the light version nor the full one on ...           6
# 281                                                 ..           0
# 282  App made really very very well. It integrates ...           4
# 283  I use it for a day and it doesn't work after t...           6
# 284  Is that compatible with German law? It is NOT ...           1
# 285  I purchased a subscription for this app in Sep...           1
# 286  I have subscribed and I have paid € 80 for a y...           1
# 287  I made a mistake by mistake. Please ask for a ...           1
# 288  for nothing no windows licens i paid for nothi...           1
# 289  which did not allow me to install a trade plat...           4
# 290                                        Unsubscribe           0
# 291  Don't like the new updated version of parellel...           6
# 292  Trial does not work.  Account setup does not w...           1
# 293  it was an accident in purchasing. now i can't ...           1
# 294  Why did I not get a messeage before the trial ...           1
# 295  After loading from the app store, you are prom...           1
# 296  After expire trial period (14 days) $79.99 was...           1
# 297  "Free" with in-app purchases\nF-ing non-functi...           1
# 298  So Far its been great, easy to use and amazed ...           6
# 299                                                now           0
# 300  After reinstalling on my iMac, I found that I ...           1
# 301  A little bit of bait-and-switch. When it was r...           1
# 302  Gentlemen, the developers are ready to buy for...           1
# 303  I was excited about this program because it wa...           4
# 304                              You should be ashamed           0
# 305  Good morning all,\nI love this application but...           4
# 306         boot camp failed 10 times  this JUST WORKS           6
# 307  Software stopped working at the end of the tri...           1
# 308  I activated the subscription and it has been v...           4
# 309  Latest update rendered software unusable UNLES...           1
# 310  With the new update you have to pay also for t...           1
# 311  You don't even get a trial with this it instan...           1
# 312  I purchased parallels 8 back in the day to run...           1
# 313                                     C.f. headline.           0
# 314        It does its job without creating headaches.           0
# 315  Your computer has the ability to run Windows a...           6
# 316  Be careful !!, they set an automatic subscript...           1
# 317  This is now a paid service, no longer free to ...           1
# 318  I was using relatively simple and stightforwar...           6
# 319  It was great during the 14 day trial.  I paid ...           1
# 320  The subscription policy is, in itself, absolut...           1
# 321  I made the purchase of the license right when ...           1
# 322  Lite is supposed to be free. It isn't. Don't b...           1
# 323  No longer free after update, should have made ...           1
# 324  I don't use windows at all. I want to use Linu...           1
# 325  Its very good to use Win with MAC \nI am media...           0
# 326  When I saw Parallels Lite was available to run...           1
# 327  How can I prevent automatic payment and cancel...           1
# 328  The term "Lite" is totally out of place.\nI ca...           1
# 329  Why do I need to buy a subscription to run my ...           1
# 330  The app does not download at all. It is downlo...           6
# 331  And how does this version now differ from para...           1
# 332  Missing from the changelog for version 1.4 is ...           1
# 333  I need to purchase the parallels desktop home ...           1
# 334  removed ability to run mac vms for free withou...           1
# 335  First of all the virtualization works find and...           4
# 336  This update failed to explain that your curren...           1
# 337  It seems good to see the introduction on the I...           1
# 338  Sad. I was using the Lite version to run Linux...           1
# 339                                               test           0
# 340  I don't know why but the app isn't getting dow...           6
# 341  Great. But forcing people to buy versions of e...           1
# 342  Before you use it, ask others if you want to b...           4
# 343  It was great during the 14 day trial.  I paid ...           1
# 344                                 Great performance.           0
# 345                                               good           0
# 346  the trial period has ended, I'm trying to buy ...           1
# 347  Is the parallels desktop for the mac that is d...           1
# 348  It's not good enough to write... Cancel subscr...           1
# 349  Not only the price is high and I have to plan ...           1
# 350                Please delete the purchase history.           1
# 351  Turns out, after grumbling so badly… It does w...           4
# 352  does not work. cannot get a refund. support us...           1
# 353  I thought I was downloading a free version of ...           1
# 354  Disappointed with trial experience with v1.4.0...           4
# 355  Hi., It says that the graphic its not compatib...           4
# 356  You need to subscribe with a 14-day free trial...           1
# 357    open up your wallet because it's no longer free           1
# 358  This is not a light version but a 14 day demo....           1
# 359  For a trial subscription, I should top up my a...           1
# 360  No subscription can not be enabled. Previously...           1
# 361  I recommend the app for people who need access...           0
# 362  There is a ton of other options, such as Virtu...           1
# 363                        Easy to use, quick, simple.           5
# 364  This is a situation where we did not want an e...           1
# 365   well so far it opens nice still figuring it out.           0
# 366  After installation, it is not possible to star...           1
# 367  The account linked to the app store cannot be ...           6
# 368  Windows  and Office works perfectly on Paralells.           4
# 369                         very fast, what I expected           5
# 370  You are very good! viva parallels desktop lite...           0
# 371  This version of Parallels clearly is limited i...           6
# 372  I've been playing around with Ubuntu a bit, mo...           1
# 373  I will immediately uninstall this app, 79 euro...           1
# 374  If you do not turn off automatic update, you w...           1
# 375                                        I'm loving!           0
# 376  Windows programs can be operated without any p...           4
# 377                    Please apply for cancellation!!           1
# 378  The developer kept saying existing user get on...           1
# 379  Purchased and cannot be used normally.\nSubscr...           1
# 380  Thanks guys for the fact that a rather conveni...           1
# 381  I have free trial for 14 days and there is no ...           1
# 382  It now requires you to buy a license. Nothing ...           1
# 383   Good software!\nToo bad the price is a drag ....           0
# 384  perfect application up to version 1.3.0 then t...           1
# 385  Parallels up to their old tricks as usual. Lin...           1
# 386  The purchase went wrong.\nI want to buy Parall...           1
# 387  Provided that the software lifts a separate, i...           1
# 388  This software used to be free to use with Linu...           1
# 389  After a free trial on the 14th, it was automat...           1
# 390  I am impressed! I was concerned at first, not ...           1
# 391  I need a virtualization program to run and tes...           1
# 392  As of version 1.4, it forces you to subscribe ...           1
# 393  Tried in the past with ubuntu and it doesn't w...           1
# 394        Money Trap wants subscription after 14 days           1
# 395  Even for linux it will ask to upgrade to a sub...           1
# 396  When I installed this it was free to run Linux...           1
# 397  It used to be free with very limited features ...           1
# 398  A subcription is now required.   I don't have ...           1
# 399  I have been using Parallels Desktop lite for a...           1
# 400    Don't use it anymore since it's a paid app now.           1
# 401  It's good to download\nI floated down to Muro ...           1
# 402  Tried Parallels to evaluate how it would behav...           1
# 403                                  Fast and Good App           5
# 404  The version notes don't mention the fact that ...           1
# 405  I was a very satisfied customer of parallels l...           1
# 406  How do I cancel my subscription? Is it cancele...           1
# 407  I've used Parallels for only a few weeks to ru...           1
# 408  I used lite version (free of charge) because i...           1
# 409  Hi there\nVERY missleading that you don't ment...           1
# 410  you are quietly working with the parallels lit...           1
# 411  Very good virtual machine but the price seems ...           1
# 412  I can't repair the premises. Please refund. I ...           1
# 413  After a year of use, the application has chang...           1
# 414  For a one-off fee of 79 euros, I would perhaps...           1
# 415  All of a sudden, I can no longer access my VMs...           1
# 416  Suddenly, with no warning, this previousy free...           1
# 417  With the latest version of the app, I have to ...           1
# 418  Today I opened it up only to find a screen say...           1
# 419  I installed Ubuntu 16.04.5 by myself. I haven'...           1
# 420  Version 1.3.3 used to be Free for running MacO...           1
# 421  with version 1.4.0 the program becomes chargea...           1
# 422  Started the app today only to find I can't acc...           1
# 423                I need support and I cannot get it.           0
# 424                           mac VMs not free anymore           1
# 425  The freemium model was much more interesting ....           1
# 426  The free version used to support Linux. Parall...           1
# 427  Latest update to 1.4 changes the free version ...           1
# 428  There was a virtualka with a tench, now only b...           1
# 429  We have the right to register for free and the...           1
# 430  $115 a year to use app. Pretty pointless. Goin...           1
# 431  I can't believe they'd pull a stunt like this....           1
# 432  Used to be free to run Linux based OS’s, now P...           1
# 433      Free use of linux away, very bad procedure !!           1
# 434             Free version doesn’t work on poppy !!!           1
# 435  The best virtualization solution I have ever u...           1
# 436  With the update to version 1.4.0, the applicat...           1
# 437  Now you need to sign up, and sign in, to use t...           1
# 438  He had the application and when updating it he...           1
# 439  I had the previous version (1.3.3) and yesterd...           1
# 440  Oops, updating tells me that I have to buy a s...           1
# 441  Everything was perfect, used only for Linux an...           1
# 442  And the point of the Lite version is now, what...           1
# 443  through an update they have also paid for the ...           1
# 444  With version 1.4.0 Parallels has a purchase ob...           1
# 445  After the update, even for Linux, a paid subsc...           1
# 446  Unfortunately I am not even allowed to run Lin...           1
# 447  After I updated it, it should be free, but now...           1
# 448  The application has just been updated and open...           1
# 449  With the 1.4 update, you are forced to sign in...           1
# 450  1.4.0 requires subscription for all OSes now.\...           1
# 451  You can use it for free for Linux and Unix (ma...           1
# 452  I just downloaded an hour ago to write a 14-da...           1
# 453  Hello.\nCompleted the 14-day trial and applied...           1
# 454  runs flawlessly and i'm super happy! \ni'm a v...           6
# 455  I think Parallels itself is much better and ea...           4
# 456  Yeah. It would be great if you could do things...           4
# 457                also works with mojave! okay thanks           6
# 458  It all runs as it should and there is actually...           4
# 459  I have found it very useful app to run macOS i...           4
# 460  As I Linux professional who works from Macs an...           6
# 461  Is external access through Parallels Access al...           4
# 462  Very good staff this app. However I am in need...           1
# 463  Bought at the end of August Parallels desktop ...           6
# 464  Virtual MacOS does not install on Parallels ve...           6
# 465       why charge me us$1 for free try 14days...???           1
# 466                                 How do you do it??           0
# 467  I bought a perpetual license over the internet...           6
# 468  fast, typical Parallels stuff (seamless integr...           4
# 469  I'm trying to install the solution and it says...           6
# 470  This is so light and still runs Windows 10. WH...           6
# 471               Does Coherence mode exist for Linux?           4
# 472  Why should I choose to pay for Parallels Deskt...           1
# 473  For me under Configuration> Hardware there is ...           4
# 474  I have been a long time VMWare Fusion user. I ...           6
# 475  I just want to try Parallels without getting i...           6
# 476  I installed macOS Mojave in my guest and the F...           4
# 477                                 PLEASE. I BEG YOU.           0
# 478  I thought that I would switch from VMWare Fusi...           6
# 479  I think it's great that you can use Windows 10...           6
# 480  I recently started using Parallels Desktop Lit...           4
# 481  I’m on the free trial, and after a few attempt...           6
# 482  try linux and windows but it goes very bad, Vi...           6
# 483  Since the trial period has expired, after purc...           6
# 484  Hello, I bought the wrong one. Please request ...           1
# 485  want to put free with in app purchases then i ...           1
# 486  It does not install, it gives me the message "...           6
# 487  I thought it was a free app and I downloaded i...           1
# 488  Extremelly excited that such a decent product ...           1
# 489  That took me a long time to find out.  I guess...           4
# 490  Wouldn’t see other computers.  Noticted gatewa...           4
# 491  It says it's free in the price section, so I d...           1
# 492  Love it. Sandboxed, lightweight, good performa...           6
# 493  Love it. Sandboxed, lightweight, good performa...           6
# 494  Love it. Sandboxed, lightweight, good performa...           6
# 495  I use the program excellent from 2013 to 2018,...           1
# 496  tried to make a yosemite vm. 3rd try seemed to...           4
# 497  This program is highly recommended for Linux f...           1
# 498  When I finished the 14 days free, I bought the...           1
# 499  ..., because the login window always shows the...           6
# 500  I bought your 1 year Windows option when my tr...           1
# 501  The truth is I love pity that it lasts 14 days...           6
# 502  purchase one time and you can only use it if u...           1
# 503  Parallels Desktop Lite is not compatible with ...           6
# 504  I pay for it 60$ , 5 days ago\nbut you didnt g...           1
# 505  I recommend I tried the wine virtual box but n...           0
# 506  Please set the price for Windows VM at least 2...           1
# 507  It is a very useful application. I would like ...           4
# 508  The Windows screenshot in the lite version des...           1
# 509  Excellent app, congratulations to the develope...           6
# 510  Neither in the description, nor on the site do...           1
# 511  Don't even waste time downloading it, it doesn...           6
# 512  This application has been the worst I ever ins...           6
# 513  Parallels Desktop Lite is a great alternative ...           6
# 514  It is great to be able to run guest operating ...           6
# 515  I bought this product but cannot activate my l...           1
# 516  My friend has Chinese AppleID and cant search ...           0
# 517  DIdn’t let me download windows.  Waste of my m...           6
# 518  To run windows you need to pay anyway. It is o...           1
# 519           VirtualBox is easier to use, and cheaper           6
# 520  I have similar problem like one of the review....           4
# 521  The Lite version has the limitation of not bei...           1
# 522  I installed 4 Linux Mint distributions and not...           6
# 523  No word in the description indicates that ther...           4
# 524  I wanted to use ubuntu and installed it.\nI tr...           4
# 525                                       not terrible           0
# 526  Hello) Thank you fo this great app. But what a...           6
# 527  It doesn’t appear the the Lite versiuon allows...           4
# 528  Great to have essential / basic features free....           1
# 529  I think this would work great, but I wasn’t ab...           6
# 530  made my life really easier, i can use OS and w...           6
# 531                                               cool           0
# 532  Since the free period was about to expire, I m...           1
# 533  I have used Parallels Desktop before I think t...           0
# 534  First of all, I’m thrilled I can get this thro...           6
# 535  Like a charm! I installed Ubuntu 16.10 from is...           6
# 536  I consider parallels the best virtualization s...           1
# 537  Very easy to use. I've got 5 Linux distributio...           1
# 538  I aways been curious to test drive chrome os, ...           6
# 539  Download 230 MB to be told that it is incompat...           6
# 540  Nothing to say, parallels is certainly the bes...           1
# 541  I think there is not much to add ... in the fa...           1
# 542  The idea - great! Finally Parallels Desktop is...           1
# 543  “Parallels Desktop Lite is not compatible with...           6
# 544  At startup, signal that it is not compatible w...           6
# 545  I already had the version bought on the develo...           0
# 546  it’s a change from the        washing\n   look...           0
# 547  I’ll still try to use Boot-camp first; like a ...           0
# 548  I used the 14 day trial to test this out, and ...           1
# 549  Here I really liked it, I even bought the lice...           4
# 550  after the 14-day trial I purchased the subscri...           1
# 551  signed up for a year? paid! I go into the prog...           1
# 552  I tried it for 14 days and tried to delete it,...           1
# 553  The two subscription plans offered are:\n• FRE...           6
# 554  Very good! The system was perfect. But I would...           5
# 555  Parallels is an amazing program. It’s unreal h...           1
# 556  It is currently free for 14 days. By the way, ...           1
# 557  In the description of the lie in the free vers...           1
# 558            Wrong purchase, please request a refund           1
# 559  This is what I was looking for. boot Camp requ...           6
# 560  I spent two days connecting the Internet in a ...           4
# 561  I installed this GMBH application and despite ...           6
# 562  Overall a pretty decent piece of software, bee...           1
# 563  Everything works great! However, the 2018 MacB...           6
# 564  I have known Parallels for a long time and aft...           5
# 565  Unfortunately, no indication that a Mac is a p...           5
# 566  Unfortunately it doesn't come with Parallels T...           4
# 567  Put this on my mac book pro. it initially says...           6
# 568  The best VM i used by far, unfortunately in th...           6
# 569  I clicked Download to say it's free, but cance...           1
# 570  I tried all the time to install the 14-day tri...           1
# 571  in many years I have tried and used many appli...           1
# 572  The app was purchased with the wrong choice. P...           1
# 573  Thunderbolt is supported in Parallesls Deskop,...           4
# 574  Well now Im bummed, wanted to try this to inst...           6
# 575  This app is not accessible with voiceover on t...           4
# 576  Once in a while, I need to run a Linux or a ma...           6
# 577                             it couldn't be better.           0
# 578  In general, it is not clear why this product i...           1
# 579  Downloaded this app as my mac is compatible ac...           6
# 580               Wrong purchase. We request a refund.           1
# 581  I want to get refund.\nI bought a wrong progra...           1
# 582  The computer cpu fan sounds too loud and seems...           5
# 583  Sure you can download this app for free. But y...           1
# 584  It's working perfectly. But do I have a questi...           1
# 585  I am now at peace with Parallels! Michael the ...           4
# 586  I am now at peace with Parallels! Michael the ...           4
# 587  I am now at peace with Parallels! Michael the ...           4
# 588  I have run both Lite and the full edition on m...           4
# 589  Currently Parallels in the only virtualisation...           6
# 590  After paying for it as a good app, the screen ...           6
# 591  I was trying to get this to work on my new mac...           6
# 592  The only thing that worked great was the insta...           4
# 593  I have a macOS VM (last OS version) to perform...           4
# 594  Wrong purchase. I want to switch to another ap...           1
# 595  I have a 15” Macbook Pro (specs way above requ...           5
# 596  Masthead!\nBut, in the light version there are...           4
# 597  A month ago I bought a parallel, but right now...           6
# 598  If there was the possibility of a one-time pur...           1
# 599  I initially wanted to use this just for linux ...           1
# 600  why do you need to pay for this app? I use thi...           1
# 601  hi \ni dont see any options to install chrome ...           4
# 602  Hello,\nLinux programs run perfectly. If you w...           6
# 603  very nice app. fully-functional FREE linux vm ...           4
# 604  3 linux systems… only 3… i need ubuntu- thats ...           6
# 605  By far, this is the best version of Parallels ...           4
# 606  It seems that the Parallel Desktop Lite produc...           1
# 607  Linux is where I would rather go than Windows,...           1
# 608  I downloaded this then realized that to run Wi...           1
# 609  Slick look, but there are a few issues. So far...           4
# 610  The product was purchased with the wrong choic...           1
# 611  Update: Hello, I am glad to say I gave this mo...           1
# 612  The purchase went wrong.\nI want to cancel my ...           1
# 613  An excellent and very useful application, it h...           6
# 614  Follow the link "Parallels Desktop Lite Suppor...           6
# 615  Please cancel your card. It was purchase not s...           1
# 616  No question unrealistic incomprehensible or wh...           6
# 617  I installed, launched, installed and enjoy! Th...           6
# 618  Okay, I understand very well what kind of Wind...           1
# 619  Very stable and refined application, I recomme...           6
# 620  Conclusion:\nAs the App Store only says that t...           6
# 621  While I don’t believe this to be worth $60 a y...           6
# 622  If you are looking to instal windows then its ...           5
# 623  … Installed the AppStore version and when I op...           6
# 624  I thought this was going to be a great solutio...           1
# 625  Another app that can only be tested after prio...           6
# 626  Great for Linux fans ! It is now possible to r...           6
# 627  Installation of Ubuntu ran without problems, a...           4
# 628  I could not install my original copy of Window...           6
# 629  I like the ability to boot multiple operating ...           4
# 630  (I made it easy to translate/understand.)\nI w...           1
# 631  but I wish they had an up to date version of D...           1
# 632                      COULDN’T. Waste of time/money           0
# 633  Unfortunately most people did not understand w...           1
# 634  I bought it for the first time,\nKorean-Englis...           4
# 635                          Thanks for free software.           1
# 636  Note: You can only run Linux with this version...           1
# 637                      Its not working on Hi Sierra.           6
# 638  One of the best solutions for running a virtua...           6
# 639  One Click Installation of Virtual Machines.\nF...           4
# 640                                              cuper           0
# 641  I purchased a one-year license, but it was not...           1
# 642  I couldn't find a line on the AppStore saying ...           1
# 643  I have accumulated 4 keys to this program. Wha...           1
# 644  Please confirm. I paid for it last time, but i...           1
# 645  Would rather buy a real Pc then let this under...           1
# 646  My processor is 64bit and I have 8gb of ram dd...           6
# 647  Windows can run with Parallels Desktop Light, ...           1
# 648              Better put the free .... it's simple.           1
# 649  There were 2 options before, free for Linux & ...           1
# 650  The latest version 1.4 now also requires a sub...           4
# 651  What should I do to buy a permanent version ot...           1
# 652  hangs, hangs and hangs. its not a stable platf...           6
# 653  Hi all,\nI have a trial version now.. and look...           1
# 654  I haven't used it since the free trial, but I ...           1
# 655   Perfect for school projects that require Windows           6
# 656  It seems that Parallels Desktop is a better ch...           0
# 657          Can't connect to the internet with this!!           4
# 658  It doesn't give me the option to cancel my sub...           1
# 659  Formerly free to use with Linux distributions,...           1
# 660  There were some errors in the previous version...           6
# 661  tried bootcamp and had problem with drivers an...           6
# 662                                            IT SLOW           5
# 663  Just downloaded the program today still on tra...           0
# 664  I renewed the 1-year license, but the restorat...           6
# 665  Yes it appears to have a 14-day trial, but you...           1
# 666  You guys ruined what could have been a great e...           1
# 667  Don't download this! 74GBP when downloaded fro...           1
# 668  There is no better and smoother way to integra...           6
# 669  What is the point of offering a "free" light v...           1
# 670                                Just. easy. Humanly           0
# 671  I have new Mac with only USB-C ports. \nwanted...           4
# 672  $79.99 a year and it doesn't even include a wi...           1
# 673  Defanately going to buy once my free trial is ...           1
# 674  App can not be used you will be asked to pay d...           1
# 675  It was written that it was free for 14 days, s...           1
# 676  It seems to have moved to a subscription servi...           1
# 677  running a quad core I7 mac\nand its running li...           6
# 678  After using it well, when I start small, the s...           6
# 679  Delivered, worked for a year, but the resource...           1
# 680                         working well. satisfied ;)           0
# 681  First require registration? and then 6000 a ye...           1
# 682  But let alone if they give you a FREE lite ver...           1
# 683                             best program by far!!!           0
# 684  It was given the opportunity to use Linux dist...           1
# 685  It is a good app, it only remains to partially...           5
# 686  After using the free trial version on the 14th...           1
# 687  This is not a free app.  This is a 14 day tria...           1
# 688  NOTHING COMPATIBLE AFTER TWO HOURS IT ALREADY ...           6
# 689  Stop future use during the 14-day trial period...           1
# 690  It turns out that this Lite version is no long...           1
# 691  I bought it but after a couple of months it wo...           1
# 692  PLN 369.99 per year 😅😂🤣 I will, however, stay ...           1
# 693  At startup, activation of the subscription is ...           1
# 694  vmx file is converted from windows platform to...           6
# 695  SINCE YOU HAVE SENT A SIMPLE STANDARD RESPONSE...           1
# 696  I used it in a good app\nI want to cancel the ...           1
# 697                                      Great program           0
# 698                               AN EXCELLENT PRODUCT           0
# 699  In the past they allowed you to run Linux mach...           1
# 700  the first connection worked fine, install a dr...           6
# 701  To run gpu demanding task takes a little bit o...           5
# 702  The application works perfectly but when I wan...           4
# 703  Suddenly, after 14 days, it is paid. Why is it...           1
# 704  Very good application for virtualizing Linux d...           6
# 705  I downloaded the free trial version of Paralle...           1
# 706  On December 20, 2018, Corel took over Parallel...           1
# 707       This solves Mac and PC compatibility issues.           0
# 708  As I was uncomfortable using Windows on my Mac...           1
# 709  This application is waste of time even if dist...           1
# 710  Edge has terrible memory leakes. Edge is a ter...           4
# 711  Great product ..  Generosity would generate a ...           0
# 712  What is a “LITE” version for if it costs as mu...           1
# 713                               this app doesnt work           6
# 714  It's just a payment, but I can't update it.\nP...           6
# 715  When you open it, you need to buy it. There is...           1
# 716  Works fine in general and I prefer it to the o...           6
# 717  I want to cancel the 14-day trial, but I don't...           1
# 718  I was using 1.3, but I clicked without hesitat...           1
# 719  I tried to install and a problem arose, I chos...           6
# 720  The subscription has ended, it’s impossible to...           1
# 721  Perfect! I just want to know how much it will ...           1
# 722  The guest drivers do not compile under Linux (...           4
# 723  I think it's less than 14 days of free use, bu...           1
# 724  I like this app since you can use windows imme...           4
# 725                                          very nice           0
# 726  The previous version worked great, but this ve...           6
# 727   I have the license for 8 and I can't use it ....           6
# 728  This is the first time I ever write a review, ...           4
# 729  Parallels Lite used to run Linux guests for fr...           1
# 730  The best emulator, but to say that it’s free a...           1
# 731  This app used to be way better, because if you...           1
# 732  $80 a year to buy a lite version so I can spen...           1
# 733  I tried to cancel after a free trial on the 14...           1
# 734  I just wanted to fire up a linux VM and play a...           1
# 735  I installed the app, but I didn't use it and d...           1
# 736  I'm impressed you get people to pay so much fo...           1
# 737  Dude i dont know what happened, but this does'...           6
# 738  As already a few others mentioned.. Not inform...           1
# 739  I am not using it because it has no use. Pleas...           1
# 740  I have been trying to cancel this subscription...           1
# 741  With the software from the manufacturer itself...           6
# 742  Runs great! Easy to drag and drop files betwee...           4
# 743  The application works very well, it is easy to...           1
# 744  If you are unable to provide Linux-based suppo...           1
# 745  The developers are liars. They wrote that Linu...           1
# 746  I LOVE THIS APP IT DOES WHAT IT SUPPOSE TO DO!...           5
# 747                            Very good, I recommend!           0

# %%
frame_uni = pd.concat([frame, frame2], ignore_index=True)

# %%
frame_uni
# Out:
#                                                  review  categories
# 0     Paid for 1 year for 3990 rubles, but the licen...           1
# 1                                    beyond expectation           0
# 2                                             very good           0
# 3     There was a two-week trial version\nI made a p...           1
# 4     The charges are too expensive, and they are ch...           1
# ...                                                 ...         ...
# 1018  Use this application for about 6 years already...           5
# 1019  Unable to get through to customer support to r...           1
# 1020  Followed the student discount offer on their s...           1
# 1021  It is a terrible product. I worked with v10 an...           4
# 1022  GREAT COMPANY \nGREAT SERVICE\nGREAT SUPPORTIN...           4
#
# [1023 rows x 2 columns]

# %%
frame2 = pd.read_csv('TrustPilot_categories.csv', header=0, sep=',')

# %%
frame_uni.to_csv('union_categories.csv', sep=',', header=True, index=False)

# %%
# Перемешивание датафрейма
frame_uni.sample(frac=1).reset_index(drop=True)
# Out:
#                                                  review  categories
# 0     hi \ni dont see any options to install chrome ...           4
# 1             bad performance with ubuntu 18 and Mac OS           5
# 2     I was trying to get this to work on my new mac...           6
# 3     I was used to Parallels 15\ndownloaded from th...           4
# 4     If you are unable to provide Linux-based suppo...           1
# ...                                                 ...         ...
# 1018  I have similar problem like one of the review....           4
# 1019  ..., because the login window always shows the...           6
# 1020  Excellent product and so easy to install on a ...           6
# 1021  I bought Parallels back when it first came out...           4
# 1022  Unfortunately I am not even allowed to run Lin...           1
#
# [1023 rows x 2 columns]

# %%
frame_uni[frame_uni['categories'].isin([6])].shape
# Out:
# (251, 2)

# %%
teaching_frame = frame_uni[:767]
testing_frame = frame_uni[767:]

# %%
teaching_frame.to_csv('teaching_categories.csv', sep=',', header=True, index=False)
testing_frame.to_csv('testing_categories.csv', sep=',', header=True, index=False)

# %% [markdown]
# # Предварительная обработка

# %%
import nltk
from nltk.corpus import PlaintextCorpusReader
from nltk.probability  import FreqDist
from nltk.tokenize import RegexpTokenizer
from nltk import bigrams
from nltk import pos_tag
from nltk.stem import WordNetLemmatizer
from collections import OrderedDict
from sklearn.metrics import classification_report, accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import GridSearchCV
from sklearn.utils import shuffle
from multiprocessing import Pool
import numpy as np
from scipy.sparse import csr_matrix
import pandas as pd

# %%
def lower_pos_tag(words):
    lower_words = []
    for i in words:
        lower_words.append(i.lower())
    pos_words = pos_tag(lower_words)
    return pos_words

# %%
def clean(words):
    wordnet_lemmatizer = WordNetLemmatizer()
    cleaned_words = []
    types = ['JJ', 'JJR', 'JJS', 
             'MD', 'NN', 'NNS', 
             'NP', 'NPS', 'POS', 
             'PP', 'RB', 'RBR', 
             'RBS', 'VV', 'VVD', 
             'VVG', 'VVN', 'VVP', 'VVZ']
    for i in words:
        if i[1] in types:
            cleaned_words.append(wordnet_lemmatizer.lemmatize(i[0]))
    return cleaned_words

# %%
def get_review_by_categories(data_path, category):
    frame = pd.read_csv(data_path, header=0, sep=',')
    return frame[frame['categories'].isin([category])].review.to_list()

def get_review_by_label(data_path, label):
    if (label == 'payment'):
        return get_review_by_categories(data_path, 1)
    elif (label == 'functionality'):
        return get_review_by_categories(data_path, 4)
    elif (label == 'speed'):
        return get_review_by_categories(data_path, 5)
    elif (label == 'integration'):
        return get_review_by_categories(data_path, 6)
    elif (label == 'stuff'):
        return get_review_by_categories(data_path, 0)
    else:
        return None

def process(data_path, label):
    # Wordmatrix - список документов с лексемами
    # All words - список всех слов
    data = {'Word_matrix': [], 'All_words': []}
    # Промежуточный список для удаления гапаксов
    templist_allwords = []
    reviews = get_review_by_label(data_path, label)
    # Создание токенайзера
    tokenizer = RegexpTokenizer(r'\w+|[^\w\s]+')
    for review in reviews: # Обработка корпуса
        bag_words = tokenizer.tokenize(review)
        lower_words = lower_pos_tag(bag_words)
        cleaned_words = clean(lower_words)
        finalist = list(bigrams(cleaned_words)) + cleaned_words
        data['Word_matrix'].append(finalist)
        templist_allwords.extend(cleaned_words)
    # Определение гапаксов
    templistfreq = FreqDist(templist_allwords)
    hapaxes = templistfreq.hapaxes()
    # Фильтрация от гапаксов
    for word in templist_allwords:
        if word not in hapaxes:
            data['All_words'].append(word)
    return {label: data}

# %% [markdown]
# # Векторизация

# %%
# Создание помеченный данных со структурой:
# [([список слов отзыва], метка_класса)]
def union_data(data):
    labels = ['payment', 'functionality', 'speed', 'integration', 'stuff']
    labeled_data = []
    for label in labels:
        for document in data[label]['Word_matrix']:
            labeled_data.append((document, label))
    return labeled_data

# %%
def vocabular_create(labels, data):
    # Создание вокабуляра с уникальными лексемами
    all_words = [] 
    for label in labels:
        frequency = FreqDist(data[label]['All_words'])
        common_words = frequency.most_common(1000)
        words = [i[0] for i in common_words]
        all_words.extend(words)
    # Извлечение уникальных лексем
    unique_words = list(OrderedDict.fromkeys(all_words))
    return unique_words

# %%
 def frequency_coding(labeled_data, unique_words):
    # Частотное кодирование для классификаторов scikit-learn
    # Разреженная матрица для признаков
    matrix_vec = csr_matrix((len(labeled_data), len(unique_words)), dtype=np.int8).toarray()
    # Массив для меток классов
    target = np.zeros(len(labeled_data), 'str')
    for index_doc, document in enumerate(labeled_data):
        for index_word, word in enumerate(unique_words):
            # Подсчет кол-ва вхождения слова в отзыв
            matrix_vec[index_doc, index_word] = document[0].count(word)
        target[index_doc] = document[1]
    return matrix_vec, target

# %% [markdown]
# # Обучение модели

# %%
# Считывание, обработка и векторизация обучающих данных
teaching_data = {}
labels = ['payment', 'functionality', 'speed', 'integration', 'stuff']
for label in labels:
    teaching_data.update(process('teaching_categories.csv', label))

unique_words = vocabular_create(labels, teaching_data)

matrix_vec, target = frequency_coding(union_data(teaching_data), unique_words)

# Перемешиваем датасет
X, Y = shuffle(matrix_vec, target)

model = MultinomialNB(0.1)
model.fit(X, Y)
# Out:
# MultinomialNB(alpha=0.1, class_prior=None, fit_prior=True)

# %% [markdown]
# # Тестирование

# %%
# Считывание, обработка и векторизация обучающих данных
testing_data = {}
labels = ['payment', 'functionality', 'speed', 'integration', 'stuff']
for label in labels:
    testing_data.update(process('testing_categories.csv', label))

# %%
# Векторизация теста
X_test, Y_test = frequency_coding(union_data(testing_data), unique_words)

# Перемешиваем датасет
X, Y = shuffle(X_test, Y_test)

# %%
predicted = model.predict(X_test)
# Точность на контрольном датасете
score_test = accuracy_score(Y_test, predicted)
# Классификационный отчет
report = classification_report(Y_test, predicted)

print(score_test)
print(report)
# Out:
# 0.390625
#               precision    recall  f1-score   support
#
#            f       0.57      0.28      0.37        72
#            i       0.40      0.48      0.44        92
#            p       0.07      0.40      0.11         5
#            s       0.41      0.39      0.40        87
#
#     accuracy                           0.39       256
#    macro avg       0.36      0.39      0.33       256
# weighted avg       0.45      0.39      0.40       256
