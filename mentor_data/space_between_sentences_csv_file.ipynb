# %%
lst = []
with open('appstore_parallels_modified.csv', 'r') as f:
    lst.extend(f.readlines())

lst_str = ''
for i in lst:
    lst_str += i

new_lst = re.split(r',[1-5],(?:(?:-1|0|1)\n', lst_str)
    
with open('appstore_parallels_modified_spaced.csv', 'w') as f:
    f.writelines(line + '\n;\n\n;\n\n' for line in new_lst)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-991927c233c0> in <module>
#       7     lst_str += i
#       8
# ----> 9 new_lst = re.split(r',[1-5],[(?:-1)01]\n', lst_str)
#      10
#      11 with open('appstore_parallels_modified_spaced.csv', 'w') as f:
#
# ~/opt/anaconda3/lib/python3.7/re.py in split(pattern, string, maxsplit, flags)
#     211     and the remainder of the string is returned as the final element
#     212     of the list."""
# --> 213     return _compile(pattern, flags).split(string, maxsplit)
#     214
#     215 def findall(pattern, string, flags=0):
#
# ~/opt/anaconda3/lib/python3.7/re.py in _compile(pattern, flags)
#     284     if not sre_compile.isstring(pattern):
#     285         raise TypeError("first argument must be string or compiled pattern")
# --> 286     p = sre_compile.compile(pattern, flags)
# ...

# %%
import re

# %%
new_lst
# Out:
# ['review,stars,status\nThe perfect solution for Mac people who have no option but to use a Windows app.....',
#  '"Great program. A few minor bugs noted, extremely minor detail. If you are looking to switch between platforms with ease and work in a Windows environment you have found the program. Great customer service if you experience any issue. I highly recommend!"',
#  '"Parallels is awesome. If you like plying old nostalgic PC games, and you have just bought a Mac, then this is the right application for you. It works perfectly and is one of the best purchases I have made. It is a little pricy for the top features, but affordable for a one-time purchase, you just don’t get all of the features, like remote access.\n\nGive it a try and you won’t regret it."',
#  '"it\'s very good , and use easily"',
#  'Very user friendly and easy to use.',
#  'Excellent software and the best part is the excellent support given to us during the covid19 situation.',
# ...
